# %%
import matplotlib.pyplot as plt
import numpy as np
import random
import math
from IPython.display import display, HTML
import json
import pathlib

# %%
def load_config(fname):
    d = {}
    if pathlib.Path(fname).is_file():
        with open(fname,"r") as f:
            d = json.load(f)
    else:
        id = input("Student Id")
        name = input("Student Name")
        d["student_id"] = id
        d["student_name"] = name
        with open(fname,"w") as f:
            json.dump(d,f)
    return d

config=load_config("config.json")
print(config)

# %% [markdown]
# <!-- <div class="question_frame"> --><!-- start of question_frame -->

# %%
t = """

        <h1>Cerebellar Model Articulation Controller</h1>
        <div class="question_body">
             
<p>Abel's Cerebellar Model Articulation Controller (CMAC) is a type of controller that is used for controlling motions. 
It is based on the structure and function of the cerebellum in the human brain, which is responsible for coordinating movement and balance.
It uses tile coding to represent the input space and a set of weights to determine the output. The weights may be encoded using
a table or a neural network.
</p>

<p>Given in the figure below is a sample CMAC controller with 18 cells.</p>

<div>


           <a download="Sample Control Problem" href="data:image/png;base64,...">

           
    <img src="data:image/png;base64,..." alt="Sample Control Problem"/>
    
</a>

</div>

<p>
The current implementation of the CMAC controller is based on a simple table lookup. A cell is activated if the value of the input p is within the range of the cell, that is
range_min <= p < range_max. The value of the cell is the value of the cell at the time of activation. The output of the CMAC controller is the sum of the values of all activated cells.
</p>

<p>The current cell table is shown below:</p>


<table  class="cell_table" "  id="cell_table" > 

        <thead>
          <tr>
        
<th>
Cell
</th>

<th>
Value
</th>

<th>
Range Min (included)
</th>

<th>
Range_Max (not included)
</th>

          </tr>
        </thead>
        
<tbody>

<tr>
<td>A</td>
<td>
0
</td>

<td>
0.00
</td>

<td>
2.00
</td>

</tr>

<tr>
<td>B</td>
<td>
0
</td>

<td>
2.00
</td>

<td>
4.00
</td>

</tr>

<tr>
<td>C</td>
<td>
-1
</td>

<td>
4.00
</td>

<td>
6.00
</td>

</tr>

<tr>
<td>D</td>
<td>
0
</td>

<td>
6.00
</td>

<td>
8.00
</td>

</tr>

<tr>
<td>E</td>
<td>
0
</td>

<td>
8.00
</td>

<td>
10.00
</td>

</tr>

<tr>
<td>F</td>
<td>
-1
</td>

<td>
0.00
</td>

<td>
0.67
</td>

</tr>

<tr>
<td>G</td>
<td>
-1
</td>

<td>
0.67
</td>

<td>
2.67
</td>

</tr>

<tr>
<td>H</td>
<td>
0
</td>

<td>
2.67
</td>

<td>
4.67
</td>

</tr>

<tr>
<td>I</td>
<td>
0
</td>

<td>
4.67
</td>

<td>
6.67
</td>

</tr>

<tr>
<td>J</td>
<td>
-1
</td>

<td>
6.67
</td>

<td>
8.67
</td>

</tr>

<tr>
<td>K</td>
<td>
-1
</td>

<td>
8.67
</td>

<td>
10.00
</td>

</tr>

<tr>
<td>L</td>
<td>
-1
</td>

<td>
0.00
</td>

<td>
1.33
</td>

</tr>

<tr>
<td>M</td>
<td>
-1
</td>

<td>
1.33
</td>

<td>
3.33
</td>

</tr>

<tr>
<td>N</td>
<td>
-1
</td>

<td>
3.33
</td>

<td>
5.33
</td>

</tr>

<tr>
<td>O</td>
<td>
-1
</td>

<td>
5.33
</td>

<td>
7.33
</td>

</tr>

<tr>
<td>P</td>
<td>
-1
</td>

<td>
7.33
</td>

<td>
9.33
</td>

</tr>

<tr>
<td>Q</td>
<td>
-1
</td>

<td>
9.33
</td>

<td>
10.00
</td>

</tr>

</tbody>
</table>


        </div><!-- end of question_body -->
    
"""
display(HTML(t))

# %% [markdown]
# <div class="question_marks"><span class="mark_num" style="text-align:right">5</span> marks</div><!-- end of question_marks -->

# %% [markdown]
# <p>Calculate the current output of the CMAC controller for the input p = 2.21.</p><p>Enter your answe in the cell below.</p>

# %% [markdown]
# cmac(p) =

# %% [markdown]
# <!-- </div> --><!-- end of question_frame -->

# %% [markdown]
# <!-- <div class="question_frame"> --><!-- start of question_frame -->

# %%
t = """

        <h1>Cerebellar Model Articulation Controller - Update</h1>
        <div class="question_body">
             
<p>The correct output for the input p = 2.21 should be 0.40.</p>

<p>The CMAC algorithm uses a learning rate of alpha = 3.90 to update the weights of the cells.</p>

        </div><!-- end of question_body -->
    
"""
display(HTML(t))

# %% [markdown]
# <div class="question_marks"><span class="mark_num" style="text-align:right">5</span> marks</div><!-- end of question_marks -->

# %% [markdown]
# <p>Calculate the current output of the CMAC controller for the input p = 2.21.</p><p>Enter your answe in the cell below.</p>

# %% [markdown]
# Updated table cells

# %% [markdown]
# <!-- </div> --><!-- end of question_frame -->
